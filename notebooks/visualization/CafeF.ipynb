# %% [markdown]
# # Import thư viện

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Đọc dữ liệu

# %%
#df_vnindex = pd.read_csv(r"C:\Users\Admin\Desktop\TANPHAT\hocotruong\Năm ba 2025-2026\HK1_A\Thu thập và tiền xử lý dữ liệu\Đồ_án_GDP\data\processed\VNINDEX_processed.csv")

# %%
df_vnindex = pd.read_csv(r"C:\Users\LAPTOP\OneDrive\Documents\TH-Thuthapdulieu\đồ án txldl\--_-n_GDP-main\--_-n_GDP-main\data\processed\VNINDEX_processed.csv")

# %% [markdown]
# # Khám phá sơ bộ

# %%
df_vnindex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6133 entries, 0 to 6132
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           6133 non-null   object
#  1   vnindex_close  6133 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 96.0+ KB

# %%
# Ép kiểu cột date về datetime
df_vnindex["date"] = pd.to_datetime(df_vnindex["date"], errors="coerce")
df_vnindex = df_vnindex[
        (df_vnindex['date'].dt.year >= 2010) & 
        (df_vnindex['date'].dt.year <= 2024)
    ].copy()

# %%
df_vnindex.describe()
# Out:
#                                 date  vnindex_close
# count                           3741    3741.000000
# mean   2017-07-07 03:06:41.283079424     812.270278
# min              2010-01-04 00:00:00     336.730000
# 25%              2013-10-04 00:00:00     512.600000
# 50%              2017-07-10 00:00:00     759.740000
# 75%              2021-04-06 00:00:00    1063.760000
# max              2024-12-31 00:00:00    1528.570000
# std                              NaN     319.029906

# %% [markdown]
# # Vẽ biểu đồ (Line Chart)

# %%
plt.figure(figsize=(12,5))
plt.plot(df_vnindex['date'], df_vnindex['vnindex_close'], label='VNINDEX Close', color='blue')

# Tính giá trị trung bình
mean_value = df_vnindex['vnindex_close'].mean()

# Vẽ đường trung bình
plt.axhline(y=mean_value, color='red', linestyle='--', linewidth=2, label=f'Mean = {mean_value:.2f}')

plt.title('VNINDEX Daily Closing Price', fontsize=14)
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Xu hướng dài hạn: Tăng trưởng mạnh mẽ từ 2009 đến 2024, dù có chu kỳ điều chỉnh.
#
# Đỉnh cao lịch sử: Khoảng 1500 điểm (năm 2022).
#
# Rủi ro: Các cú giảm mạnh thường đi kèm biến cố toàn cầu (COVID, chính sách tiền tệ).
#
# Cơ hội: Mức hiện tại (2024) vẫn cao hơn trung bình dài hạn, cho thấy thị trường đang ổn định trong vùng cao.
